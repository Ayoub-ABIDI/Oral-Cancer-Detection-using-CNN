# %% [markdown]
# We will:
#
# Resize and center crop (ensures focus on the mouth area)
#
# Normalize pixel values
#
# Augment data to prevent overfitting
#
# Use custom preprocessing logic with tf.data API for more flexibility and speed

# %%
import tensorflow as tf
import os

# Settings
IMG_SIZE = 128
BATCH_SIZE = 16
AUTOTUNE = tf.data.AUTOTUNE

# Paths
data_dir = "DataSet"

# Define preprocessing function
def preprocess_image(image, label):
    # Resize and center crop
    image = tf.image.resize(image, [IMG_SIZE + 20, IMG_SIZE + 20])
    image = tf.image.central_crop(image, central_fraction=IMG_SIZE / (IMG_SIZE + 20))
    
    # Normalize [0,255] → [0,1]
    image = tf.cast(image, tf.float32) / 255.0
    
    return image, label

# Data augmentation function
def augment(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    image = tf.image.random_rotation(image, 0.05)  # if using tf_addons
    return image, label

# Load dataset using image_dataset_from_directory
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

# Apply preprocessing and augmentation
train_ds = (
    train_ds
    .map(preprocess_image, num_parallel_calls=AUTOTUNE)
    .map(augment, num_parallel_calls=AUTOTUNE)
    .shuffle(100)
    .prefetch(AUTOTUNE)
)

val_ds = (
    val_ds
    .map(preprocess_image, num_parallel_calls=AUTOTUNE)
    .prefetch(AUTOTUNE)
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import tensorflow as tf
#       2 import os
#       4 # Settings
#
# File c:\Users\ayoub\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:55
#      53 from tensorflow._api.v2 import autograph
#      54 from tensorflow._api.v2 import bitwise
# ---> 55 from tensorflow._api.v2 import compat
#      56 from tensorflow._api.v2 import config
#      57 from tensorflow._api.v2 import data
#
# File c:\Users\ayoub\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\compat\__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File c:\Users\ayoub\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py:30
#      28 from tensorflow._api.v2.compat.v1 import autograph
#      29 from tensorflow._api.v2.compat.v1 import bitwise
# ---> 30 from tensorflow._api.v2.compat.v1 import compat
#      31 from tensorflow._api.v2.compat.v1 import config
#      32 from tensorflow._api.v2.compat.v1 import data
#
# File c:\Users\ayoub\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.compat import v1
#       9 from tensorflow._api.v2.compat.v1.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File c:\Users\ayoub\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v1\__init__.py:36
#      34 from tensorflow._api.v2.compat.v1 import distribute
#      35 from tensorflow._api.v2.compat.v1 import distributions
# ---> 36 from tensorflow._api.v2.compat.v1 import dtypes
#      37 from tensorflow._api.v2.compat.v1 import errors
#      38 from tensorflow._api.v2.compat.v1 import experimental
#
# File c:\Users\ayoub\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\compat\v1\dtypes\__init__.py:8
#       3 """Public API for tf._api.v2.dtypes namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.dtypes import experimental
#       9 from tensorflow.python.ops.gen_string_ops import as_string # line: 29
#      10 from tensorflow.python.framework.dtypes import DType # line: 51
#
# File c:\Users\ayoub\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\compat\v1\dtypes\experimental\__init__.py:8
#       3 """Public API for tf._api.v2.dtypes.experimental namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.framework.dtypes import float8_e4m3b11fnuz # line: 465
#       9 from tensorflow.python.framework.dtypes import float8_e4m3fn # line: 439
#      10 from tensorflow.python.framework.dtypes import float8_e4m3fnuz # line: 452
#
# ImportError: cannot import name 'float8_e4m3b11fnuz' from 'tensorflow.python.framework.dtypes' (c:\Users\ayoub\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\dtypes.py)
